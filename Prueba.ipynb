# %% [markdown]
# <a href="https://colab.research.google.com/github/BryanMorelosA/Untitled6.ipynb/blob/main/Prueba.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# instalar librerias

# %%
# !pip install pandas
# !pip install numpy

# %% [markdown]
# Importar biblioteca

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# extracción de datos
url="https://raw.githubusercontent.com/FalsetoBryan/lab/refs/heads/main/fichero_lab_unir.csv"
data = pd.read_csv(url)
data.head(1000)
#data
# Out:
#      Unnamed: 0 num_expediente       fecha      hora  \
# 0             0    2021S000047  01/01/2021  11:38:00
# 1             1    2021S000142  04/01/2021  11:30:00
# 2             2    2021S000142  04/01/2021  11:30:00
# 3             3    2021S000142  04/01/2021  11:30:00
# 4             4    2021S000142  04/01/2021  11:30:00
# ..          ...            ...         ...       ...
# 995         150    2022S007773  21/03/2022  17:20:00
# 996         151    2022S007862  22/03/2022  18:50:00
# 997         152    2022S007862  22/03/2022  18:50:00
# 998         153    2022S008094  24/03/2022  10:00:00
# 999         154    2022S008117  22/03/2022  17:15:00
#
#                                           localizacion numero  cod_distrito  \
# 0    CALL. JOSE BERGAMIN / CALL. FLORENCIO CANO CRI...     62            14
# 1     PLAZA. GRECIA / AVDA. ARCENTALES wanda farola 20      1            20
# 2     PLAZA. GRECIA / AVDA. ARCENTALES wanda farola 20      1            20
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2349 entries, 0 to 2348
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            2349 non-null   int64
#  1   num_expediente        2349 non-null   object
#  2   fecha                 2349 non-null   object
#  3   hora                  2349 non-null   object
#  4   localizacion          2349 non-null   object
#  5   numero                2349 non-null   object
#  6   cod_distrito          2349 non-null   int64
#  7   distrito              2349 non-null   object
#  8   tipo_accidente        2349 non-null   object
#  9   estado_meteorológico  2265 non-null   object
#  10  tipo_vehículo         845 non-null    object
#  11  tipo_persona          2349 non-null   object
#  12  rango_edad            2349 non-null   object
#  13  sexo                  2349 non-null   object
#  14  cod_lesividad         2004 non-null   float64
# ...

# %%
nulos = data.isnull().sum()
nulos
# Out:
# Unnamed: 0                 0
# num_expediente             0
# fecha                      0
# hora                       0
# localizacion               0
# numero                     0
# cod_distrito               0
# distrito                   0
# tipo_accidente             0
# estado_meteorológico      84
# tipo_vehículo           1504
# tipo_persona               0
# rango_edad                 0
# sexo                       0
# cod_lesividad            345
# tipo_lesividad          1619
# coordenada_x_utm           0
# coordenada_y_utm           0
# positiva_alcohol           4
# positiva_droga          2345
# tipo_vehiculo            845
# lesividad               1075
# dtype: int64

# %%
#valores unicos
data.nunique()
# Out:
# Unnamed: 0               878
# num_expediente          2108
# fecha                    866
# hora                     489
# localizacion            1962
# numero                   330
# cod_distrito              21
# distrito                  21
# tipo_accidente            11
# estado_meteorológico       5
# tipo_vehículo              2
# tipo_persona               3
# rango_edad                18
# sexo                       3
# cod_lesividad              8
# tipo_lesividad             7
# coordenada_x_utm        2103
# coordenada_y_utm        2106
# positiva_alcohol           2
# positiva_droga             1
# tipo_vehiculo              2
# lesividad                  8
# dtype: int64

# %%
data.value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
print(data['sexo'].unique())
# Out:
# ['Hombre' 'Mujer' 'Desconocido']

# %%
print(data['sexo'].nunique())
# Out:
# 3

# %%
# deccribe los valores numericos
data.describe()
# Out:
#         Unnamed: 0  cod_distrito  cod_lesividad  positiva_droga
# count  2349.000000   2349.000000    2004.000000             4.0
# mean    398.985951      8.485313       5.783932             1.0
# std     238.559110      5.775349       3.966500             0.0
# min       0.000000      1.000000       1.000000             1.0
# 25%     195.000000      3.000000       2.000000             1.0
# 50%     391.000000      8.000000       6.000000             1.0
# 75%     587.000000     13.000000       7.000000             1.0
# max     877.000000     21.000000      14.000000             1.0

# %%
# describe los valores categoricos /object
data.describe(include=['object'])
# Out:
#        num_expediente       fecha      hora                   localizacion  \
# count            2349        2349      2349                           2349
# unique           2108         866       489                           1962
# top       2021S000142  01/06/2022  13:30:00  CTRA. CIUDAD UNIVERSITARIA, 0
# freq                4           9        24                              8
#
#        numero distrito tipo_accidente estado_meteorológico tipo_vehículo  \
# count    2349     2349           2349                 2265           845
# unique    330       21             11                    5             2
# top         1   CENTRO          Caída            Despejado     Bicicleta
# freq      247      294            721                 1993           691
#
#        tipo_persona       rango_edad    sexo  \
# count          2349             2349    2349
# unique            3               18       3
# top       Conductor  De 25 a 29 años  Hombre
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2349 entries, 0 to 2348
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            2349 non-null   int64
#  1   num_expediente        2349 non-null   object
#  2   fecha                 2349 non-null   object
#  3   hora                  2349 non-null   object
#  4   localizacion          2349 non-null   object
#  5   numero                2349 non-null   object
#  6   cod_distrito          2349 non-null   int64
#  7   distrito              2349 non-null   object
#  8   tipo_accidente        2349 non-null   object
#  9   estado_meteorológico  2265 non-null   object
#  10  tipo_vehículo         845 non-null    object
#  11  tipo_persona          2349 non-null   object
#  12  rango_edad            2349 non-null   object
#  13  sexo                  2349 non-null   object
#  14  cod_lesividad         2004 non-null   float64
# ...

# %% [markdown]
# # COMPROBACION DE OUTLIERS

# %%
num_cols=data.select_dtypes(include='number').columns

for col in num_cols:
  plt.figure(figsize=(17,1))
  sns.boxplot(data=data[num_cols], x=col)

# %%
#Nº de Outliers usando rango IQR
outliers={}

for col in num_cols:
  Q1 = np.percentile(data[col], 25)
  Q3 = np.percentile(data[col], 75)
  IQR = Q3 - Q1
  lower_bound = Q1 - 1.5 * IQR
  upper_bound = Q3 + 1.5 * IQR
  outliers[col]= (data[col] > upper_bound).sum() + (data[col]< lower_bound).sum()

print(outliers)
# Out:
# {'Unnamed: 0': 0, 'cod_distrito': 0, 'cod_lesividad': 0, 'positiva_droga': 0}

# %%
#Nº de Outliers usando 2 std
outliers={}
for col in num_cols:
  mean=data[col].mean()
  std=data[col].std()

  outliers[col] = (data[col] > (mean + 2 *std)).sum() + (data[col] < (mean - 3 *std)).sum()

print(outliers)
# Out:
# {'Unnamed: 0': 1, 'cod_distrito': 52, 'cod_lesividad': 264, 'positiva_droga': 0}

# %%
sns.histplot(data['cod_distrito'])
# Out:
# <Axes: xlabel='cod_distrito', ylabel='Count'>
